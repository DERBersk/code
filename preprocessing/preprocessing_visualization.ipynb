# %% [markdown]
# ## Find points in images that correspond to most fixated on regions

# %%
from fixation_centroids import calculate_fixation_centroids
from visualize import visualize_fixations_and_centroids

# %%
import os
import pandas as pd

# %%
for path in os.listdir('/home/simon/Documents/studium/seminar1_a-eye/Projektseminar_EWS_SoSe25/code/preproces''s/events/fixations/'):
    if path.endswith('10100.parquet') and path.startswith('P01'):
        full_path = os.path.join('/home/simon/Documents/studium/seminar1_a-eye/Projektseminar_EWS_SoSe25/code/preprocess/events/fixations/', path)
        centroids = calculate_fixation_centroids(full_path)
        visualize_fixations_and_centroids(full_path, centroids, title=f'Fixation Points with Centroids for {path}')
        print(f'Centroids for {path}: {centroids}')
# Out:
# Centroids for P01_IMG005_10100.parquet: [[0.29211553290784337, 0.29553042990768413], [0.741676716533067, 0.3155016880474496]]
# Centroids for P01_IMG004_10100.parquet: [[0.3151401551618628, 0.3500710515706795], [0.6640873485910797, 0.5400706500137533]]
# Centroids for P01_IMG001_10100.parquet: [[0.19987838513659176, 0.3253948144086794], [0.7030678714741245, 0.6731364382960543], [0.876876480803696, 0.8341132591644868]]
# Centroids for P01_IMG009_10100.parquet: [[0.22219615009394628, 0.358992800649708]]
# Centroids for P01_IMG008_10100.parquet: [[0.7913166749476447, 0.16830413884971734], [0.23085342336760648, 0.5801134848249644], [0.10672268899230031, 0.22206458579339258]]
# Centroids for P01_IMG002_10100.parquet: [[0.326880069935408, 0.30554752257183787], [0.7911240775754234, 0.3327471410601122]]
